# %% [markdown]
# # Specific Examples
#
# Worked examples organized by structure type. Each row is identified by an **M-CODE** ([arxiv](https://www.arxiv.org/abs/2602.14384)). Table style follows the [repository README](../../../README.ipynb).
#
# | Domain | Dimensionality | Category | M-CODE | Notebook | Description |
# | ------ | -------------- | -------- | ------ | -------- | ----------- |
# | Pristine Structures | 3D | Ideal Crystal | `P-3D-CRY` | — | *To be added* |
# | Pristine Structures | 2D | Monolayer | `P-2D-MNL` | — | *To be added* |
# | Pristine Structures | 2D | Slab | `P-2D-SLB-S` | [Simple Slab: SrTiO₃ (structure)](slab_strontium_titanate.ipynb) | SrTiO₃ slab |
# | Pristine Structures | 2D | Slab | `P-2D-SLB-R` | — | Reconstructed slab; *to be added* |
# | Pristine Structures | 1D | Nanotape | `P-1D-NTP` | — | *To be added* |
# | Pristine Structures | 1D | Nanowire | `P-1D-NWR` | — | *To be added* |
# | Pristine Structures | 0D | Nanoparticle | `P-0D-NPR` | [Gold Nanocluster (structure)](nanocluster_gold.ipynb) | Gold nanocluster |
# | Pristine Structures | 0D | Nanoribbon | `P-0D-NRB` | — | *To be added* |
# | Compound Pristine Structures | 2D | Heterostack | `C-2D-HST` | [Si/SiO₂/HfO₂/TiN Heterostructure (structure)](heterostructure_silicon_silicon_dioxide_hafnium_dioxide_titanium_nitride.ipynb) | High-κ metal gate stack |
# | Compound Pristine Structures | 2D | Interface Simple | `C-2D-INT-S` | — | *To be added* |
# | Compound Pristine Structures | 2D | Interface ZSL | `C-2D-INT-Z` | [BN/Graphene 2D–2D Interface (structure)](interface_2d_2d_boron_nitride_graphene.ipynb) | 2D–2D interface |
# | Compound Pristine Structures | 2D | Interface ZSL | `C-2D-INT-Z` | [Graphene/SiO₂ 2D–3D Interface (structure)](interface_2d_3d_graphene_silicon_dioxide.ipynb) | 2D–3D interface |
# | Compound Pristine Structures | 2D | Interface ZSL | `C-2D-INT-Z` | [Cu/Cristobalite 3D–3D Interface (structure)](interface_3d_3d_copper_cristobalite.ipynb) | 3D–3D interface |
# | Compound Pristine Structures | 2D | Interface ZSL | `C-2D-INT-Z` | [Graphene/Ni Interface Film XY Position Optimization (structure)](optimization_interface_film_xy_position_graphene_nickel.ipynb) | Interface optimization |
# | Compound Pristine Structures | 2D | Interface Twisted | `C-2D-INT-T` | — | *To be added* |
# | Compound Pristine Structures | 2D | Interface Commensurate Lattice | `C-2D-INT-C` | [Twisted Commensurate MoS₂ Bilayer (structure)](interface_bilayer_twisted_commensurate_lattices_molybdenum_disulfide.ipynb) | Twisted bilayer MoS₂ |
# | Compound Pristine Structures | 2D | Multi-Layer | `C-2D-MLT` | — | *To be added* |
# | Compound Pristine Structures | 0D | Nanoribbons Interface Rotation | `C-0D-INT-R` | [Twisted BN Nanoribbon Bilayer (structure)](interface_bilayer_twisted_nanoribbons_boron_nitride.ipynb) | Twisted BN nanoribbons |
# | Defective Structures | 3D | Amorphous | `D-3D-AMO` | — | *To be added* |
# | Defective Structures | 2D | Adatom | `D-2D-ADA` | [Pt Adatom/Island on MoS₂ (structure)](defect_point_adatom_island_molybdenum_disulfide_platinum.ipynb) | Pt on MoS₂ |
# | Defective Structures | 2D | Adatom | `D-2D-ADA` | [Adatom on Graphene (structure)](defect_surface_adatom_graphene.ipynb) | Metal adatom on graphene |
# | Defective Structures | 2D | Grain Boundary Planar | `D-2D-GBP` | [Grain Boundary in 2D BN (structure)](defect_planar_grain_boundary_2d_boron_nitride.ipynb) | h-BN grain boundary |
# | Defective Structures | 2D | Grain Boundary Planar | `D-2D-GBP` | [Grain Boundary in 3D FCC Cu (structure)](defect_planar_grain_boundary_3d_fcc_metals_copper.ipynb) | Cu grain boundary |
# | Defective Structures | 2D | Island | `D-2D-ISL` | [TiN Island on Surface (structure)](defect_surface_island_titanium_nitride.ipynb) | Island defect on TiN |
# | Defective Structures | 2D | Terrace | `D-2D-TER` | [Step/Terrace on Pt Surface (structure)](defect_surface_step_platinum.ipynb) | Pt step/terrace |
# | Defective Structures | 1D | Grain Boundary Linear | `D-1D-GBL` | — | *To be added* |
# | Defective Structures | 0D | Defect Pair | `D-0D-DFP` | [Defect Pair in GaN (structure)](defect_point_pair_gallium_nitride.ipynb) | Vacancy–substitution pair |
# | Defective Structures | 0D | Interstitial | `D-0D-INT` | [Interstitial in SnO₂ (structure)](defect_point_interstitial_tin_oxide.ipynb) | O interstitial in SnO |
# | Defective Structures | 0D | Substitution | `D-0D-SUB` | [N-doped Graphene (structure)](defect_point_substitution_graphene.ipynb) | Substitutional N in graphene |
# | Defective Structures | 0D | Substitution | `D-0D-SUB` | [N-doped Graphene Band Structure (simulation)](defect_point_substitution_graphene_simulation.ipynb) | Electronic structure |
# | Defective Structures | 0D | Vacancy | `D-0D-VAC` | [Vacancy in BN (structure)](defect_point_vacancy_boron_nitride.ipynb) | Vacancy in h-BN |
# | Processed Structures | 3D | Perturbation | `X-3D-PER` | — | *To be added* |
# | Processed Structures | 3D | Annealed Crystal | `X-3D-ANL` | — | *To be added* |
# | Processed Structures | 2D | Perturbation | `X-2D-PER` | [Ripple Perturbation in Graphene (structure)](perturbation_ripple_graphene.ipynb) | Rippled graphene |
# | Processed Structures | 2D | Passivated Surface | `X-2D-PAS` | [Silicon Surface Passivation (structure)](passivation_surface_silicon.ipynb) | H-terminated Si(100) |
# | Processed Structures | 1D | Passivated Edge | `X-1D-PAS` | [Si Nanowire Edge Passivation (structure)](passivation_edge_nanowire_silicon.ipynb) | H-passivated Si nanowire |
# | Processed Structures | 0D | Passivated Edge | `X-0D-PAS` | — | *To be added* |
# | Processed Structures | 0D | Slab Cutout | `X-0D-CUT` | [Custom Cutout in Etched Silicon (structure)](custom_cutout_etched_silicon.ipynb) | Etched Si cutout |
