# %% [markdown]
# # Overview
#
# Returns a list of materials that you have access to.
#
# # Parameters
#
# 1. **HOST**: Hostname of the RESTful API server. Defaults to platform.exabyte.io.
#
# 2. **PORT**: The port RESTful API server is listening on. Defaults to 443.
#
# 3. **VERSION**: RESTFul API version. Defaults to 2018-10-01.
#
# 4. **SECURE**: Whether to use secure connection. Defaults to True.
#
# 5. **ACCOUNT_ID**: Your account ID.
#
# 6. **AUTH_TOKEN**: Your authentication token.

# %%
import json
import argparse

from endpoints.login import LoginEndpoint
from endpoints.materials import MaterialEndpoints

# %%
HOST = 'platform.exabyte.io'
PORT = 443
SECURE = True
VERSION = "2018-10-01"
ACCOUNT_ID = "knJyjbqxww7kt4GpA"
AUTH_TOKEN = "Jh6umOZqjfTQldC4gMnObb-rdoiNMg87ga0yZ-wcnQ9"

# %%
materials_endpoint = MaterialEndpoints(HOST, PORT, account_id=ACCOUNT_ID, auth_token=AUTH_TOKEN, VERSION, SECURE)
materials = materials_endpoint.list()

# %%
print json.dumps(materials, indent=4)
# Out:
# [
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "hY77F3hvNXy5RhepE",
#             "slug": "exadmin",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "99eWqT5e24k3TmFAq",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "JQFkKP9kBrm43ojKH",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "TGkRw3nAfGknLopzJ",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ozAH2YTj65AN5MQz3",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "oQhBpSFuxTqe7AtFY",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gFhXf9FWzKG6v6z8K",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-11-01T02:24:38.139Z",
#         "owner": {
#             "_id": "knJyjbqxww7kt4GpA",
#             "slug": "exadmin",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T01:23:49.411Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": false,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "tkmEX2KdrSzgo54km"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "Sbhv32auoAD3Xdeqk",
#             "slug": "demo",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "BXLHWoNbE3YbqdzSw",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "QpHXMJpv8R9ejzgqF",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "tb7vE23nxodR4hBqg",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "oxjr3ygrjshZwi98z",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "Dmmqrx7muFYy3NCWR",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "Jfmo66aZxm8qAEPwD",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T01:23:51.571Z",
#         "owner": {
#             "_id": "8nRSiEbyTvW4MRHrz",
#             "slug": "demo",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T01:23:51.448Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "aQwQb6B7A8KWuXgAw"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "c7BCrzijYNEJ2a2xZ",
#             "slug": "user-w7jtotjm6n",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "DCNHWAnsKFYiAHHw9",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "aKrDxKuFxZYm987tY",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "QFHvPeBg5KSe8NpPs",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "224maqXDx2wBn8suC",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "MAh7saCdvaEmMYnFJ",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "bPoNKis6qzrGBtdic",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T17:05:27.631Z",
#         "owner": {
#             "_id": "Agu2Kt5a6cEWiKJgq",
#             "slug": "user-w7jtotjm6n",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T17:05:27.526Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "kWsf9r6wE6jS5eEqq"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "6WteQqQJAfCvX97ju",
#             "slug": "user-myd1irpmnt",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "zcXQTzx3YGN3SCXpB",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "urahe3dwbRhgzZ97E",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "5MKsbZTthho6687wE",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "meW4kR7DuuxMbY6qF",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gWJts9xqFmDYkwKfE",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "NTMzfAbd3GYhEFmPy",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T17:46:41.724Z",
#         "owner": {
#             "_id": "HvrXF9EJ7iPDgQ42w",
#             "slug": "user-myd1irpmnt",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T17:46:41.607Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "M58EiS6aXbNDyzR5y"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "yC4jYF4G8DYr3vooQ",
#             "slug": "user-h2ns2gzpe5",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "J8dFzLeJgqTZzyLaM",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "HbhBSg2W66bFiFqJw",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "AXJd7j4hgSqqXDhoM",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "MQmzBZm9C4JNzDNuN",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "GKBFhavNfqhLuEGj9",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "NGsh32h2khjpdpkkA",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T17:50:46.351Z",
#         "owner": {
#             "_id": "p3cqJHM3CzdddpZip",
#             "slug": "user-h2ns2gzpe5",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T17:50:46.245Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "MscKbKdfzb3vkYPnP"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "cp8BeMcdDysGyJLpC",
#             "slug": "user-uxfm7zr5ib",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "7aavtpqMA9gsCo5Gy",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "2dY4rrFg7sZCnx5Xj",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "CvBJ7sxawpFPPJihg",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "m9KBLkKCYBaWdgopS",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "EvYvybzR3ictuxeEa",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "Hjp69zN2ACBBnFKGX",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T22:50:33.530Z",
#         "owner": {
#             "_id": "6PnNmvxboQ3XE6GeA",
#             "slug": "user-uxfm7zr5ib",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T22:50:33.416Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "etkLvTHbPwzdapTBD"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "LDmrEttY9uxdEAaLu",
#             "slug": "user-g6cs61z6rv",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "SLMegFne6uwq8W4Kb",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "Rfx2DBEep2jWxdvg5",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "FS5dG5y4ATujWYCuS",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "CNxpnSqGWufkiT9WK",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "CBjpF9tGt7ypete5P",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ANwnvXqDF2pgQCfxX",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T22:50:39.587Z",
#         "owner": {
#             "_id": "Qnzgcw8NKBu2xFCsv",
#             "slug": "user-g6cs61z6rv",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T22:50:39.143Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "bvDorD3DPcMvCdcWs"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "tE3J5knfvxMrTxPiA",
#             "slug": "user-utn5zwxyth",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "q2wyTAEXDseYRmZhZ",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "amg3L4wJ9cS7d6ww5",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ETGJ2D7hHq8riuCoS",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "RCWDs2ckRxwvkgELh",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "APzSA5kcziHbob2qr",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "8mmypQLKG3EQLnrTA",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-29T22:52:05.358Z",
#         "owner": {
#             "_id": "HbbjZqtWwmePHXqqh",
#             "slug": "user-utn5zwxyth",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-29T22:52:05.238Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "eiysWthK6iA6JziJw"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "hY77F3hvNXy5RhepE",
#             "slug": "exadmin",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "yWakGtvrLG6xDbiCE",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gwEzCTtbkFqaySK3r",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "6qZfxyzXLxhsn78k2",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "N6vcyzw6T6Gyws7nX",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "nwtawEsubjwfpDD4v",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "v4rcR4FXfCLG8sB2z",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-10-31T02:57:13.216Z",
#         "owner": {
#             "_id": "hD9wE8bqtyM5g6XLz",
#             "slug": "exabyte",
#             "cls": "Account"
#         },
#         "createdAt": "2018-10-31T02:57:13.057Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC",
#         "_id": "7xTHmW9n6BbSDCaAd"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "hY77F3hvNXy5RhepE",
#             "slug": "exadmin",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "99eWqT5e24k3TmFAq",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "JQFkKP9kBrm43ojKH",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "TGkRw3nAfGknLopzJ",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ozAH2YTj65AN5MQz3",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "oQhBpSFuxTqe7AtFY",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gFhXf9FWzKG6v6z8K",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-11-01T02:24:38.115Z",
#         "owner": {
#             "_id": "knJyjbqxww7kt4GpA",
#             "slug": "exadmin",
#             "cls": "Account"
#         },
#         "createdAt": "2018-11-01T02:20:38.192Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": true,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC (clone)",
#         "_id": "JXPvFDmTMbv73BsjT"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "hY77F3hvNXy5RhepE",
#             "slug": "exadmin",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "99eWqT5e24k3TmFAq",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "JQFkKP9kBrm43ojKH",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "TGkRw3nAfGknLopzJ",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ozAH2YTj65AN5MQz3",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "oQhBpSFuxTqe7AtFY",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gFhXf9FWzKG6v6z8K",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-11-01T02:21:17.747Z",
#         "owner": {
#             "_id": "knJyjbqxww7kt4GpA",
#             "slug": "exadmin",
#             "cls": "Account"
#         },
#         "createdAt": "2018-11-01T02:21:17.464Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": false,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC (clone) (clone)",
#         "_id": "gT7c7hLwv3vk5g5KM"
#     },
#     {
#         "isEntitySet": false,
#         "creator": {
#             "_id": "hY77F3hvNXy5RhepE",
#             "slug": "exadmin",
#             "cls": "User"
#         },
#         "scaledHash": "87e416358789a7c435eaaba0344af51d",
#         "nSites": 2,
#         "inSet": [
#             {
#                 "_id": "c8bEk9FLFoLrbF7Dj",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "99eWqT5e24k3TmFAq",
#                 "slug": "admin",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "JQFkKP9kBrm43ojKH",
#                 "slug": "owner",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "TGkRw3nAfGknLopzJ",
#                 "slug": "read",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "ozAH2YTj65AN5MQz3",
#                 "slug": "comment",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "oQhBpSFuxTqe7AtFY",
#                 "slug": "execute",
#                 "cls": "Team"
#             },
#             {
#                 "_id": "gFhXf9FWzKG6v6z8K",
#                 "slug": "edit",
#                 "cls": "Team"
#             }
#         ],
#         "updatedAt": "2018-11-01T02:22:18.343Z",
#         "owner": {
#             "_id": "knJyjbqxww7kt4GpA",
#             "slug": "exadmin",
#             "cls": "Account"
#         },
#         "createdAt": "2018-11-01T02:22:18.141Z",
#         "basis": {
#             "units": "crystal",
#             "cell": [
#                 [
#                     1,
#                     0,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     1.6081226496766366e-16,
#                     1,
#                     6.123233995736766e-17
#                 ],
#                 [
#                     0,
#                     0,
#                     1
#                 ]
#             ],
#             "elements": [
#                 {
#                     "id": 0,
#                     "value": "Si"
#                 },
#                 {
#                     "id": 1,
#                     "value": "Si"
#                 }
#             ],
#             "coordinates": [
#                 {
#                     "id": 0,
#                     "value": [
#                         0,
#                         0,
#                         0
#                     ]
#                 },
#                 {
#                     "id": 1,
#                     "value": [
#                         0.25,
#                         0.25,
#                         0.25
#                     ]
#                 }
#             ]
#         },
#         "lattice": {
#             "a": 3.867,
#             "c": 3.867,
#             "b": 3.867,
#             "vectors": {
#                 "a": [
#                     3.34892,
#                     0,
#                     1.9335
#                 ],
#                 "units": "angstrom",
#                 "c": [
#                     0,
#                     0,
#                     3.867
#                 ],
#                 "b": [
#                     1.116307,
#                     3.157392,
#                     1.9335
#                 ],
#                 "alat": 1
#             },
#             "beta": 60,
#             "units": {
#                 "length": "angstrom",
#                 "angle": "degree"
#             },
#             "alpha": 60,
#             "type": "FCC",
#             "gamma": 60
#         },
#         "unitCellFormula": "Si2",
#         "formula": "Si",
#         "isDefault": false,
#         "exabyteId": "qDygiN7tkEXewoePy",
#         "elements": [
#             "Si"
#         ],
#         "hash": "a665723ef7429caef6ca89385fe25bae",
#         "tags": [],
#         "nElements": 1,
#         "derivedProperties": [
#             {
#                 "units": "angstrom^3",
#                 "name": "volume",
#                 "value": 40.88909687039703
#             },
#             {
#                 "units": "g/cm^3",
#                 "name": "density",
#                 "value": 2.281149390789523
#             },
#             {
#                 "tolerance": {
#                     "units": "angstrom",
#                     "value": 0.3
#                 },
#                 "name": "symmetry",
#                 "spaceGroupSymbol": "Fd-3m"
#             },
#             {
#                 "name": "elemental_ratio",
#                 "value": 1,
#                 "element": "Si"
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 0
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 2
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 3
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 5
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 7
#             },
#             {
#                 "value": 1,
#                 "name": "p-norm",
#                 "degree": 10
#             }
#         ],
#         "schemaVersion": "0.2.0",
#         "name": "Silicon FCC (clone) (clone) (clone)",
#         "_id": "NpKQhatSL2gJo34w5"
#     }
# ]
