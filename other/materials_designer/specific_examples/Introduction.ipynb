# %% [markdown]
# # Specific Examples
#
# Examples of structures and properties calculations from well-known publications organized by structure type. Each row is identified by an **M-CODE** ([arxiv](https://www.arxiv.org/abs/2602.14384)).
#
# Domain (`P` - Pristine, `C` - Compound Pristine, `D` - Defective, `X` - Processed) - Dimensionality - Category - Variant (if applicable)
#
#
# | M-CODE | Category | Notebook | Type |
# | ------ | -------- | -------- | ---- |
# | `P-3D-CRY` | Ideal Crystal | *To be added* | — |
# | `P-2D-MNL` | Monolayer | *To be added* | — |
# | `P-2D-SLB-S` | Slab | [Simple Slab: SrTiO₃](slab_strontium_titanate.ipynb) | structure |
# | `P-2D-SLB-R` | Slab | *Reconstructed slab. To be added* | — |
# | `P-1D-NTP` | Nanotape | *To be added* | — |
# | `P-1D-NWR` | Nanowire | *To be added* | — |
# | `P-0D-NPR` | Nanoparticle | [Gold Nanocluster](nanocluster_gold.ipynb) | structure |
# | `P-0D-NRB` | Nanoribbon | *To be added* | — |
# | `C-2D-HST` | Heterostack | [Si/SiO₂/HfO₂/TiN Heterostructure](heterostructure_silicon_silicon_dioxide_hafnium_dioxide_titanium_nitride.ipynb) | structure |
# | `C-2D-INT-S` | Interface Simple | *To be added* | — |
# | `C-2D-INT-Z` | Interface ZSL | [BN/Graphene 2D–2D Interface](interface_2d_2d_boron_nitride_graphene.ipynb) | structure |
# | `C-2D-INT-Z` | Interface ZSL | [Graphene/SiO₂ 2D–3D Interface](interface_2d_3d_graphene_silicon_dioxide.ipynb) | structure |
# | `C-2D-INT-Z` | Interface ZSL | [Cu/Cristobalite 3D–3D Interface](interface_3d_3d_copper_cristobalite.ipynb) | structure |
# | `C-2D-INT-Z` | Interface ZSL | [Graphene/Ni Interface Film XY Position Optimization](optimization_interface_film_xy_position_graphene_nickel.ipynb) | structure |
# | `C-2D-INT-T` | Interface Twisted | *To be added* | — |
# | `C-2D-INT-C` | Interface Commensurate Lattice | [Twisted Commensurate MoS₂ Bilayer](interface_bilayer_twisted_commensurate_lattices_molybdenum_disulfide.ipynb) | structure |
# | `C-2D-MLT` | Multi-Layer | *To be added* | — |
# | `C-0D-INT-R` | Nanoribbons Interface Rotation | [Twisted BN Nanoribbon Bilayer](interface_bilayer_twisted_nanoribbons_boron_nitride.ipynb) | structure |
# | `D-3D-AMO` | Amorphous | *To be added* | — |
# | `D-2D-ADA` | Adatom | [Pt Adatom/Island on MoS₂](defect_point_adatom_island_molybdenum_disulfide_platinum.ipynb) | structure |
# | `D-2D-ADA` | Adatom | [Adatom on Graphene](defect_surface_adatom_graphene.ipynb) | structure |
# | `D-2D-GBP` | Grain Boundary Planar | [Grain Boundary in 2D BN](defect_planar_grain_boundary_2d_boron_nitride.ipynb) | structure |
# | `D-2D-GBP` | Grain Boundary Planar | [Grain Boundary in 3D FCC Cu](defect_planar_grain_boundary_3d_fcc_metals_copper.ipynb) | structure |
# | `D-2D-ISL` | Island | [TiN Island on Surface](defect_surface_island_titanium_nitride.ipynb) | structure |
# | `D-2D-TER` | Terrace | [Step/Terrace on Pt Surface](defect_surface_step_platinum.ipynb) | structure |
# | `D-1D-GBL` | Grain Boundary Linear | *To be added* | — |
# | `D-0D-DFP` | Defect Pair | [Defect Pair in GaN](defect_point_pair_gallium_nitride.ipynb) | structure |
# | `D-0D-INT` | Interstitial | [Interstitial in SnO₂](defect_point_interstitial_tin_oxide.ipynb) | structure |
# | `D-0D-SUB` | Substitution | [N-doped Graphene](defect_point_substitution_graphene.ipynb) | structure |
# | `D-0D-SUB` | Substitution | [N-doped Graphene Band Structure](defect_point_substitution_graphene_simulation.ipynb) | simulation |
# | `D-0D-VAC` | Vacancy | [Vacancy in BN](defect_point_vacancy_boron_nitride.ipynb) | structure |
# | `X-3D-PER` | Perturbation | *To be added* | — |
# | `X-3D-ANL` | Annealed Crystal | *To be added* | — |
# | `X-2D-PER` | Perturbation | [Ripple Perturbation in Graphene](perturbation_ripple_graphene.ipynb) | structure |
# | `X-2D-PAS` | Passivated Surface | [Silicon Surface Passivation](passivation_surface_silicon.ipynb) | structure |
# | `X-1D-PAS` | Passivated Edge | [Si Nanowire Edge Passivation](passivation_edge_nanowire_silicon.ipynb) | structure |
# | `X-0D-PAS` | Passivated Edge | *To be added* | — |
# | `X-0D-CUT` | Slab Cutout | [Custom Cutout in Etched Silicon](custom_cutout_etched_silicon.ipynb) | structure |
